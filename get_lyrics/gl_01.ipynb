# %%
# https://music.youtube.com/watch?v=kNZ5P0AAlmg&feature=share

# %%
import requests
import re
import regex
import time
import os, json
from urllib.request import urlopen
from datetime import datetime
from bs4 import BeautifulSoup

# %%
# BeautifulSoup으로 사이트 소스 가져오기(HTML)
def get_soup(url, charset):
    '''
    url: 사이트 링크
    charset: 사이트의 인코딩 방식
    '''
    headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/85.0.4183.102 Safari/537.36'}
    # python으로 사이트에 접속할 때 python-requests/2.21.0 등으로 표시가 되면 정보를 제공하지 않아 header를 따로 설정
    res = requests.get(url, headers=headers)
    res.raise_for_status()
    # 요청/응답 코드가 200이면 True, 아니면 False를 반환
    res.encoding = None
    soup = BeautifulSoup(res.content.decode(charset, 'replace'), 'html.parser')
    return soup

# %%
# 웹사이트 인코딩 방식 확인
def get_encoding(url):
    f = urlopen(url)
    bytes_content = f.read()
    # bytes 자료형의 응답 본문을 변수에 저장
    
    # cahrset은 HTML의 앞부분에 적혀 있는 경우가 대부분, 앞부분의 1024byte만 ASCII문자로 디코딩
    scanned_text = bytes_content[:1024].decode('ascii', errors='replace')
    
    # 디코딩한 문자열에서 re를 이용해 charset값 추출, 만약 명시되어 있지 않다면 UTF-8사용
    match = re.search(r'charset=["\']?([\w-]+)', scanned_text)
    if match: encoding = match.group(1)
    else: encoding = 'utf-8'
    
    return encoding

# 서울경제>부동산>정책,제도 에서 실행해보면 'utf-8'임을 확인 할 수 있다.
get_encoding('https://music.youtube.com/watch?v=kNZ5P0AAlmg&feature=share')
# Out:
# 'utf-8'

# %%
# encoding 방식 확인 -> get_soup을 이용해 HTML코드 가져오기
url = 'https://www.youtube.com/watch?v=AixnnhUEvPw'
# url = 'https://youtu.be/HyHNuVaZJ-k'
encoding = get_encoding(url)
soup = get_soup(url, encoding)

title =soup.select('a#video-title')
# 영상 제목만 전체 조회
for i in title:
    print(i.text.strip())
    
soup
# Out:
# <!DOCTYPE html>
# <html lang="ko-KR" style="font-size: 10px;font-family: Roboto, Arial, sans-serif;" system-icons="" typography="" typography-spacing=""><head><meta content="AsKJ0YJfrprDHN9cO+Arkwlyt0SqGVbRekp6Ho6B0zL8/aWcEEa7mYjLrXVRY4E3+ZPTupaMmCxJOtl4ava9CgAAAABteyJvcmlnaW4iOiJodHRwczovL3lvdXR1YmUuY29tOjQ0MyIsImZlYXR1cmUiOiJQcml2YWN5U2FuZGJveEFkc0FQSXMiLCJleHBpcnkiOjE2Njk3NjYzOTksImlzU3ViZG9tYWluIjp0cnVlfQ==" http-equiv="origin-trial"/><script nonce="1-NzhT1xp1NppcSb60nAnA">var ytcfg={d:function(){return window.yt&&yt.config_||ytcfg.data_||(ytcfg.data_={})},get:function(k,o){return k in ytcfg.d()?ytcfg.d()[k]:o},set:function(){var a=arguments;if(a.length>1)ytcfg.d()[a[0]]=a[1];else for(var k in a[0])ytcfg.d()[k]=a[0][k]}};
# ...

# %%
https://music.youtube.com/watch?v=PErbSeBCjdY&feature
&feature=share 제외하면 youtube로 연결
https://www.youtube.com/watch?v=PErbSeBCjdY


https://music.youtube.com/watch?v=HUNQWZFuTMk&feature=share
https://www.youtube.com/
https://music.youtube.com/watch?v=AixnnhUEvPw&feature=share
https://www.youtube.com/watch?v=AixnnhUEvPw
